# %% [raw]
# This is a guide to show how to use Jupyter notebooks with VS Code

# %% [markdown]
# ![image.png](attachment:1f87358d-dfca-49c7-8e91-a3ff6630b345.png)

# %% [markdown]
# Start by opening VS Code
#     * If you don't have it downloaded,
